# %%
#Librerie utili
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
#Import the residual from 2kr excel sheet
excelSheet=pd.read_excel("../excel/2kr.xlsx")

#Lock only the part regarding residuals in the excel sheet and sto in a new dataframe
residualDataframe=excelSheet.loc[0:7,'y1-ym':'y10-ym']

#Rapid check the new dataframe
print(residualDataframe)

print(residualDataframe.values)
# Out:
#       y1-ym     y2-ym     y3-ym     y4-ym     y5-ym     y6-ym     y7-ym  \
# 0 -0.075972 -0.025139  0.027083 -0.028472  0.135139  0.036250 -0.188750
# 1  0.013194 -0.008472  0.013472 -0.020417 -0.056250 -0.010694  0.024306
# 2  0.052972 -0.016194  0.031583 -0.012028 -0.045917  0.000750  0.006861
# 3  0.037083  0.004583 -0.031806  0.050694  0.020417 -0.023750 -0.003194
# 4 -0.000722 -0.040167  0.022889  0.009556  0.044556 -0.040444 -0.010722
# 5  0.029500 -0.001056  0.005611 -0.024389 -0.013000  0.017833  0.008389
# 6  0.046667 -0.008611  0.028056 -0.002500 -0.039444  0.005000  0.003333
# 7 -0.001556  0.030389  0.012889 -0.000167  0.001222 -0.031000 -0.027389
#
#       y8-ym     y9-ym    y10-ym
# 0  0.025972  0.076250  0.017639
# 1  0.010972 -0.014306  0.048194
# 2  0.018806 -0.027583 -0.009250
# 3 -0.013472 -0.041528  0.000972
# 4  0.002333  0.021778 -0.009056
# 5 -0.017167 -0.007167  0.001444
# 6  0.014167 -0.040000 -0.006667
# 7  0.002889  0.001500  0.011222
# ...

# %%
for residual in residualDataframe.values:
    
    #Set the dimensions of the plot
    plt.figure(figsize=(10,10))
    
    qqPlot = stats.probplot(residual, dist='norm',plot=plt,rvalue=True)
    plt.title("QQ Plot for:"+columnName)
    plt.xlabel("Normal Distribution")

# %%
#TEST QQPLOT WITH A SAMPLE NORMAL DISTRIBUTION

from scipy import stats
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))

nsample = 50
np.random.seed(7654321)

x = stats.norm.rvs(loc=0, scale=1, size=nsample)
res = stats.probplot(x, plot=plt,rvalue=True)

plt.title("QQ Plot")

# %%
for (columnName, columnData) in residualDataframe.iteritems():
    
    #Set the dimensions of the plot
    plt.figure(figsize=(10,10))
    
    residuals=columnData.values
    
    qqPlot = stats.probplot(residuals, dist='norm',plot=plt,rvalue=True)
    plt.title("QQ Plot for:"+columnName)
    plt.xlabel("Normal Distribution")
