# %%
#Librerie utili
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
from scipy import stats 
import scipy.stats as st

# %%
con = sqlite3.connect("../code/omnet/simulations/results/simulates1.sca")

# %%
dfThroughput=pd.read_sql_query("""
select scenario, config, clients, CAST(attrValue as INT), statCount / 3600.0 as throughput
from runConfig rc inner join statistic s on rc.runId = s.runId
        inner join runAttr ra on s.runId = ra.runId
where statName = "completedTransactions:stats"
 AND attrName = "repetition"
order by scenario, config, clients,  CAST(attrValue as INT)
""", con)
# Out:
#    scenario config  clients  CAST(attrValue as INT)  throughput
# 0        s1     c1       49                       0   10.015833
# 1        s1     c1       49                       1   10.066667
# 2        s1     c1       49                       2   10.118889
# 3        s1     c1       49                       3   10.063333
# 4        s1     c1       49                       4   10.226944
# 5        s1     c1       49                       5   10.128056
# 6        s1     c1       49                       6    9.903056
# 7        s1     c1       49                       7   10.117778
# 8        s1     c1       49                       8   10.168056
# 9        s1     c1       49                       9   10.109444
# 10       s1     c1       49                      10   10.048611
# 11       s1     c1       49                      11   10.109167
# 12       s1     c1       49                      12   10.060000
# 13       s1     c1       49                      13   10.015278
# 14       s1     c1       49                      14    9.917222
# 15       s1     c1       49                      15   10.095556
# 16       s1     c1       49                      16    9.949167
# 17       s1     c1       49                      17   10.218056
# 18       s1     c1       49                      18   10.138889
# 19       s1     c1       49                      19    9.946944
# 20       s1     c1       49                      20   10.087778
# 21       s1     c1       49                      21   10.144167
# 22       s1     c1       49                      22   10.202778
# 23       s1     c1       49                      23   10.068611
# 24       s1     c1       49                      24    9.949722
# 25       s1     c1       49                      25   10.091389
# 26       s1     c1       49                      26   10.128611
# 27       s1     c1       49                      27   10.079444
# 28       s1     c1       49                      28   10.070278
# 29       s1     c1       49                      29   10.145556

# %%
dfThroughput['throughput_mean'] = dfThroughput.groupby(['scenario','config','clients'])['throughput'].transform('mean')
dfThroughput['throughput_residual'] = dfThroughput['throughput'] - dfThroughput['throughput_mean']

# %%
dfThroughput.tail(30)
# Out:
#     scenario config  clients  CAST(attrValue as INT)  throughput  \
# 210       s1     c8       49                       0    1.020556
# 211       s1     c8       49                       1    1.052500
# 212       s1     c8       49                       2    1.035000
# 213       s1     c8       49                       3    1.021944
# 214       s1     c8       49                       4    1.023333
# 215       s1     c8       49                       5    0.991111
# 216       s1     c8       49                       6    0.994722
# 217       s1     c8       49                       7    1.025000
# 218       s1     c8       49                       8    1.023611
# 219       s1     c8       49                       9    1.033333
# 220       s1     c8       49                      10    1.006389
# 221       s1     c8       49                      11    1.018056
# 222       s1     c8       49                      12    1.070278
# 223       s1     c8       49                      13    1.055556
# 224       s1     c8       49                      14    1.056111
# 225       s1     c8       49                      15    1.031389
# 226       s1     c8       49                      16    1.065000
# 227       s1     c8       49                      17    1.058333
# 228       s1     c8       49                      18    0.985278
# 229       s1     c8       49                      19    1.041944
# 230       s1     c8       49                      20    1.000000
# 231       s1     c8       49                      21    1.029167
# 232       s1     c8       49                      22    1.025000
# 233       s1     c8       49                      23    1.067500
# 234       s1     c8       49                      24    1.044444
# 235       s1     c8       49                      25    1.019722
# 236       s1     c8       49                      26    1.037222
# 237       s1     c8       49                      27    1.002778
# 238       s1     c8       49                      28    1.033056
# 239       s1     c8       49                      29    1.024167
#
#      throughput_mean  throughput_residual
# 210          1.02975            -0.009194
# 211          1.02975             0.022750
# 212          1.02975             0.005250
# 213          1.02975            -0.007806
# 214          1.02975            -0.006417
# 215          1.02975            -0.038639
# 216          1.02975            -0.035028
# 217          1.02975            -0.004750
# 218          1.02975            -0.006139
# 219          1.02975             0.003583
# 220          1.02975            -0.023361
# 221          1.02975            -0.011694
# 222          1.02975             0.040528
# 223          1.02975             0.025806
# 224          1.02975             0.026361
# 225          1.02975             0.001639
# 226          1.02975             0.035250
# 227          1.02975             0.028583
# 228          1.02975            -0.044472
# 229          1.02975             0.012194
# 230          1.02975            -0.029750
# 231          1.02975            -0.000583
# 232          1.02975            -0.004750
# 233          1.02975             0.037750
# 234          1.02975             0.014694
# 235          1.02975            -0.010028
# 236          1.02975             0.007472
# 237          1.02975            -0.026972
# 238          1.02975             0.003306
# 239          1.02975            -0.005583

# %%
#Set the dimensions of the plot
plt.figure(figsize=(10,10))

repThroughput=dfThroughput['throughput_residual']
qqPlot = stats.probplot(list(repThroughput), dist='norm',plot=plt,rvalue=True)
plt.title("QQ Plot for Throughput for Scenario S1 ")
plt.xlabel("Normal Distribution")
# Out:
# Text(0.5, 0, 'Normal Distribution')
